# %%
import pandas as pd

data_save = pd.read_csv("csv/103")
data_save.head()
# Out:
#   direction_name  route_id  is_active  direction_id direction_headsign  \
# 0       Outbound       103      False             0        San Joaquín
# 1       Outbound       103      False             0        San Joaquín
# 2       Outbound       103      False             0        San Joaquín
# 3       Outbound       103      False             0        San Joaquín
# 4       Outbound       103      False             0        San Joaquín
#
#    stop_headsign arrival_time  stop_sequence departure_time  shape_pt_lat  \
# 0            NaN     00:00:00              1       00:00:00    -33.428821
# 1            NaN     00:00:00              1       00:00:00    -33.429256
# 2            NaN     00:00:00              1       00:00:00    -33.429613
# 3            NaN     00:00:00              1       00:00:00    -33.429188
# 4            NaN     00:00:00              1       00:00:00    -33.429042
#
#    ...                        stop_name  start_time  trip_headsign  end_time  \
# ...

# %%
for rutas in pd.read_csv("Rutas.csv")["route_id"].unique():
    print(rutas)
# Out:
# 201
# 205
# 202c
# 203e
# 204e
# 204N
# 205e
# 209e
# 103
# 403
# 406
# 107c
# 210
# 206c
# 117c
# 219e
# 221e
# 224c
# 264N
# 125
# 302
# G01c
# 401c
# 113
# 506
# 322
# 350
# 113c
# 113e
# 301c
# 301c2
# 302e
# 302N
# 303e
# 109N
# 110c
# 408e
# 502c
# 506e
# 307c
# 307e
# 308c
# 350c
# J01c
# L4R
# I08
# I09c
# C01c
# I03c
# 102
# 104
# I04c
# 114
# 712N
# 404c
# 405c
# 406c
# 413c
# 420e
# 428c
# 428e
# 431c
# L4A
# 408
# 501
# 507c
# 514c
# J07c
# J13c
# L5
# MTN
# J18c
# 105
# F01c
# B02N
# B12c
# L1
# L2
# C02c
# L2V
# C03c
# L5V
# L6
# L3
# L4V
# MTR
# L4
# J16
# I18
# 385
# I01
# B31N
# 404
# 204
# 209
# D07
# 230
# E04
# I14
# 504
# I14N
# F30N
# H13
# I10N
# J03
# 313e
# J19
# 301
# B26
# 115
# 227
# D05
# 509
# 517
# 121
# 402
# 518
# D09N
# C10e
# L2R
# F08
# 422c
# 314c
# L5R
# 510
# B29
# 505
# D03
# B27
# 315e
# 314
# 514
# 507
# 119
# 511
# H07
# J10
# B30N
# 516
# 424
# 541N
# 503
# 409
# 422
# 519
# J13
# 426
# 513
# B20
# 508
# J05
# 515N
# H06
# 271
# H12
# 214
# ...
